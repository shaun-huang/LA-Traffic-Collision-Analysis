# %% [markdown]
# ## Project 1 - Los Angeles Traffic Collision Analysis

# %%
# import modules for the analysis environment
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# read csv file
df = pd.read_csv("Data/Raw/traffic-collision-data-from-2010-to-present.csv")
df.head()
# Out:
#    DR Number            Date Reported            Date Occurred  Time Occurred  \
# 0  190614534  2019-06-29T00:00:00.000  2019-06-29T00:00:00.000           1000
# 1  190411644  2019-06-29T00:00:00.000  2019-06-29T00:00:00.000            710
# 2  190913064  2019-06-29T00:00:00.000  2019-06-29T00:00:00.000            710
# 3  191217109  2019-06-29T00:00:00.000  2019-06-29T00:00:00.000            125
# 4  191011660  2019-06-29T00:00:00.000  2019-06-29T00:00:00.000             40
#
#    Area ID    Area Name  Reporting District  Crime Code  \
# 0        6    Hollywood                 626         997
# 1        4   Hollenbeck                 479         997
# 2        9     Van Nuys                 923         997
# 3       12  77th Street                1245         997
# 4       10  West Valley                1005         997
#
#   Crime Code Description                       MO Codes  ...  \
# 0      TRAFFIC COLLISION                            NaN  ...
# 1      TRAFFIC COLLISION                            NaN  ...
# 2      TRAFFIC COLLISION                            NaN  ...
# 3      TRAFFIC COLLISION  4025 3036 3004 3026 3029 3101  ...
# 4      TRAFFIC COLLISION                            NaN  ...
#
#    Premise Description                          Address  \
# 0               STREET  PRIMROSE                     AV
# 1               STREET  WHITTIER                     BL
# 2               STREET  VAN NUYS                     BL
# 3               STREET  VERMONT                      AV
# 4               STREET  SATICOY                      ST
#
#                       Cross Street  \
# 0  VINE                         ST
# 1  SPENCE                       ST
# 2  VANOWEN                      ST
# 3  FLORENCE                     AV
# 4  BALCOM                       AV
#
#                                             Location Zip Codes Census Tracts  \
# 0  {'latitude': '34.1098', 'longitude': '-118.326...   24033.0         405.0
# 1  {'latitude': '34.0265', 'longitude': '-118.198...   23441.0         527.0
# 2  {'latitude': '34.1939', 'longitude': '-118.448...   19733.0         236.0
# 3  {'latitude': '33.9746', 'longitude': '-118.291...   23675.0         777.0
# 4  {'latitude': '34.2084', 'longitude': '-118.520...   18909.0         253.0
#
#   Precinct Boundaries LA Specific Plans  Council Districts  \
# 0               371.0               NaN                7.0
# 1               352.0               NaN                9.0
# 2               290.0               NaN                3.0
# 3              1161.0               7.0               14.0
# 4               914.0               NaN                2.0
#
#    Neighborhood Councils (Certified)
# 0                               64.0
# 1                               38.0
# 2                               18.0
# 3                               20.0
# 4                               12.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Stats of Series in the Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478415 entries, 0 to 478414
# Data columns (total 24 columns):
# DR Number                            478415 non-null int64
# Date Reported                        478415 non-null object
# Date Occurred                        478415 non-null object
# Time Occurred                        478415 non-null int64
# Area ID                              478415 non-null int64
# Area Name                            478415 non-null object
# Reporting District                   478415 non-null int64
# Crime Code                           478415 non-null int64
# Crime Code Description               478415 non-null object
# MO Codes                             393593 non-null object
# Victim Age                           400964 non-null float64
# Victim Sex                           471443 non-null object
# Victim Descent                       470724 non-null object
# Premise Code                         478390 non-null float64
# Premise Description                  478390 non-null object
# Address                              478415 non-null object
# Cross Street                         457148 non-null object
# Location                             478415 non-null object
# Zip Codes                            478018 non-null float64
# Census Tracts                        471923 non-null float64
# Precinct Boundaries                  475345 non-null float64
# LA Specific Plans                    176007 non-null float64
# Council Districts                    472739 non-null float64
# Neighborhood Councils (Certified)    454497 non-null float64
# dtypes: float64(8), int64(5), object(11)
# memory usage: 87.6+ MB

# %% [markdown]
# ## Cleaning Data

# %%
dfclean = df.drop(columns=['DR Number', #unique value but we have index
                           'Date Reported', #repetitive series
                           'MO Codes', #mostly NaN values
                           'Crime Code', #repetitive
                           'Crime Code Description', #uniform data
                           'LA Specific Plans', #unrelated data with NaN values
                           'Area ID', #repetitive data
                           'Premise Description',#useless data 
                           'Neighborhood Councils (Certified)', #irrelevant
                           'Precinct Boundaries', #irrelevant
                           'Council Districts', # irrelevant
                           'Census Tracts']) #meaningless data
dfclean.head()
# Out:
#              Date Occurred  Time Occurred    Area Name  Reporting District  \
# 0  2019-06-29T00:00:00.000           1000    Hollywood                 626
# 1  2019-06-29T00:00:00.000            710   Hollenbeck                 479
# 2  2019-06-29T00:00:00.000            710     Van Nuys                 923
# 3  2019-06-29T00:00:00.000            125  77th Street                1245
# 4  2019-06-29T00:00:00.000             40  West Valley                1005
#
#    Victim Age Victim Sex Victim Descent  Premise Code  \
# 0         NaN          M              W         101.0
# 1        25.0          M              H         101.0
# 2        35.0          M              H         101.0
# 3        34.0          M              B         101.0
# 4        50.0          F              H         101.0
#
#                            Address                     Cross Street  \
# 0  PRIMROSE                     AV  VINE                         ST
# 1  WHITTIER                     BL  SPENCE                       ST
# 2  VAN NUYS                     BL  VANOWEN                      ST
# 3  VERMONT                      AV  FLORENCE                     AV
# 4  SATICOY                      ST  BALCOM                       AV
#
#                                             Location  Zip Codes
# 0  {'latitude': '34.1098', 'longitude': '-118.326...    24033.0
# 1  {'latitude': '34.0265', 'longitude': '-118.198...    23441.0
# 2  {'latitude': '34.1939', 'longitude': '-118.448...    19733.0
# 3  {'latitude': '33.9746', 'longitude': '-118.291...    23675.0
# 4  {'latitude': '34.2084', 'longitude': '-118.520...    18909.0

# %%
dfclean.columns = ['date','time','area','district','victim_age','victim_sex','victim_race',
                   'premise','address','cross_street','location','zip']
dfclean.head()
# Out:
#                       date  time         area  district  victim_age  \
# 0  2019-06-29T00:00:00.000  1000    Hollywood       626         NaN
# 1  2019-06-29T00:00:00.000   710   Hollenbeck       479        25.0
# 2  2019-06-29T00:00:00.000   710     Van Nuys       923        35.0
# 3  2019-06-29T00:00:00.000   125  77th Street      1245        34.0
# 4  2019-06-29T00:00:00.000    40  West Valley      1005        50.0
#
#   victim_sex victim_race  premise                          address  \
# 0          M           W    101.0  PRIMROSE                     AV
# 1          M           H    101.0  WHITTIER                     BL
# 2          M           H    101.0  VAN NUYS                     BL
# 3          M           B    101.0  VERMONT                      AV
# 4          F           H    101.0  SATICOY                      ST
#
#                       cross_street  \
# 0  VINE                         ST
# 1  SPENCE                       ST
# 2  VANOWEN                      ST
# 3  FLORENCE                     AV
# 4  BALCOM                       AV
#
#                                             location      zip
# 0  {'latitude': '34.1098', 'longitude': '-118.326...  24033.0
# 1  {'latitude': '34.0265', 'longitude': '-118.198...  23441.0
# 2  {'latitude': '34.1939', 'longitude': '-118.448...  19733.0
# 3  {'latitude': '33.9746', 'longitude': '-118.291...  23675.0
# 4  {'latitude': '34.2084', 'longitude': '-118.520...  18909.0

# %% [markdown]
# ## victim_race

# %%
race_description = {'H':'Hispanic', 'B':'Black', 'O':'Unknown', 'W':'White', 'X':'Unknown', '-':'Unknown',
                    'A':'Asian', 'K':'Asian', 'C':'Asian', 'F':'Asian', 'U':'Pacific Islander',
                    'J':'Asian', 'P':'Pacific Islander', 'V':'Asian', 'Z':'Asian',
                    'I':'American Indian', 'G':'Pacific Islander', 'S':'Pacific Islander', 
                    'D':'Asian', 'L':'Asian'}
dfclean.victim_race = dfclean.victim_race.map(race_description)
dfclean.head()
# Out:
#                       date  time         area  district  victim_age  \
# 0  2019-06-29T00:00:00.000  1000    Hollywood       626         NaN
# 1  2019-06-29T00:00:00.000   710   Hollenbeck       479        25.0
# 2  2019-06-29T00:00:00.000   710     Van Nuys       923        35.0
# 3  2019-06-29T00:00:00.000   125  77th Street      1245        34.0
# 4  2019-06-29T00:00:00.000    40  West Valley      1005        50.0
#
#   victim_sex victim_race  premise                          address  \
# 0          M       White    101.0  PRIMROSE                     AV
# 1          M    Hispanic    101.0  WHITTIER                     BL
# 2          M    Hispanic    101.0  VAN NUYS                     BL
# 3          M       Black    101.0  VERMONT                      AV
# 4          F    Hispanic    101.0  SATICOY                      ST
#
#                       cross_street  \
# 0  VINE                         ST
# 1  SPENCE                       ST
# 2  VANOWEN                      ST
# 3  FLORENCE                     AV
# 4  BALCOM                       AV
#
#                                             location      zip
# 0  {'latitude': '34.1098', 'longitude': '-118.326...  24033.0
# 1  {'latitude': '34.0265', 'longitude': '-118.198...  23441.0
# 2  {'latitude': '34.1939', 'longitude': '-118.448...  19733.0
# 3  {'latitude': '33.9746', 'longitude': '-118.291...  23675.0
# 4  {'latitude': '34.2084', 'longitude': '-118.520...  18909.0

# %% [markdown]
# ## Longitude and Latitude

# %%
import ast

# %%
dfclean['location'] = [ast.literal_eval(d) for d in dfclean.location]
dfclean['longitude'] = [d['longitude'] for d in dfclean.location]
dfclean['latitude'] = [d['latitude'] for d in dfclean.location]
dfclean.longitude = dfclean.longitude.astype(float)
dfclean.latitude = dfclean.latitude.astype(float)
dfclean.head()
# Out:
#                       date  time         area  district  victim_age  \
# 0  2019-06-29T00:00:00.000  1000    Hollywood       626         NaN
# 1  2019-06-29T00:00:00.000   710   Hollenbeck       479        25.0
# 2  2019-06-29T00:00:00.000   710     Van Nuys       923        35.0
# 3  2019-06-29T00:00:00.000   125  77th Street      1245        34.0
# 4  2019-06-29T00:00:00.000    40  West Valley      1005        50.0
#
#   victim_sex victim_race  premise                          address  \
# 0          M       White    101.0  PRIMROSE                     AV
# 1          M    Hispanic    101.0  WHITTIER                     BL
# 2          M    Hispanic    101.0  VAN NUYS                     BL
# 3          M       Black    101.0  VERMONT                      AV
# 4          F    Hispanic    101.0  SATICOY                      ST
#
#                       cross_street  \
# 0  VINE                         ST
# 1  SPENCE                       ST
# 2  VANOWEN                      ST
# 3  FLORENCE                     AV
# 4  BALCOM                       AV
#
#                                             location      zip  longitude  \
# 0  {'latitude': '34.1098', 'longitude': '-118.326...  24033.0  -118.3267
# 1  {'latitude': '34.0265', 'longitude': '-118.198...  23441.0  -118.1980
# 2  {'latitude': '34.1939', 'longitude': '-118.448...  19733.0  -118.4487
# 3  {'latitude': '33.9746', 'longitude': '-118.291...  23675.0  -118.2918
# 4  {'latitude': '34.2084', 'longitude': '-118.520...  18909.0  -118.5208
#
#    latitude
# 0   34.1098
# 1   34.0265
# 2   34.1939
# 3   33.9746
# 4   34.2084

# %%
dfclean = dfclean.drop(columns=['location'])
dfclean.to_csv('Data/Clean/cleaned_data.csv',index=False)
