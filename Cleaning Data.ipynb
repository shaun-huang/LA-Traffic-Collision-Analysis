# %% [markdown]
# ## Project 1 - Los Angeles Traffic Collision Analysis

# %%
#import modules for the analysis environment
import os
import matplotlib.pyplot as plta
import pandas as pd
import numpy as np
import requests
import time
import datetime

#read csv file
file_path = "Data/Raw/traffic-collision-data-from-2010-to-present.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#    DR Number            Date Reported            Date Occurred  Time Occurred  \
# 0  191912240  2019-06-22T00:00:00.000  2019-06-22T00:00:00.000           1150
# 1  190315354  2019-06-22T00:00:00.000  2019-06-22T00:00:00.000           1600
# 2  191011360  2019-06-22T00:00:00.000  2019-06-22T00:00:00.000            650
# 3  192111796  2019-06-22T00:00:00.000  2019-06-22T00:00:00.000            525
# 4  191512949  2019-06-22T00:00:00.000  2019-06-22T00:00:00.000            245
#
#    Area ID    Area Name  Reporting District  Crime Code  \
# 0       19      Mission                1985         997
# 1        3    Southwest                 357         997
# 2       10  West Valley                1001         997
# 3       21      Topanga                2145         997
# 4       15  N Hollywood                1543         997
#
#   Crime Code Description MO Codes  ...  Premise Description  \
# 0      TRAFFIC COLLISION      NaN  ...               STREET
# 1      TRAFFIC COLLISION      NaN  ...               STREET
# 2      TRAFFIC COLLISION      NaN  ...               STREET
# 3      TRAFFIC COLLISION      NaN  ...               STREET
# 4      TRAFFIC COLLISION      NaN  ...               STREET
#
#                            Address                     Cross Street  \
# 0  PARTHENIA                    ST  TOBIAS                       AV
# 1                        JEFFERSON                         CATALINA
# 2                           ROSCOE                          SHIRLEY
# 3  VICTORY                      BL  SHOUP                        AV
# 4  LAUREL CANYON                BL  MAGNOLIA                     BL
#
#                                             Location Zip Codes Census Tracts  \
# 0  {'latitude': '34.2279', 'human_address': '{"ad...   19730.0         144.0
# 1  {'latitude': '34.0255', 'human_address': '{"ad...   22724.0         691.0
# 2  {'latitude': '34.2204', 'human_address': '{"ad...   18909.0         101.0
# 3  {'latitude': '34.1865', 'human_address': '{"ad...    4278.0         297.0
# 4  {'latitude': '34.1649', 'human_address': '{"ad...    8890.0         205.0
#
#   Precinct Boundaries LA Specific Plans  Council Districts  \
# 0               417.0               NaN                3.0
# 1               913.0               7.0               14.0
# 2              1545.0               NaN                2.0
# 3              1473.0               NaN                4.0
# 4              1332.0              17.0                5.0
#
#    Neighborhood Councils (Certified)
# 0                               59.0
# 1                               32.0
# 2                               65.0
# 3                               49.0
# 4                               39.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Stats of Series in the Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477377 entries, 0 to 477376
# Data columns (total 24 columns):
# DR Number                            477377 non-null int64
# Date Reported                        477377 non-null object
# Date Occurred                        477377 non-null object
# Time Occurred                        477377 non-null int64
# Area ID                              477377 non-null int64
# Area Name                            477377 non-null object
# Reporting District                   477377 non-null int64
# Crime Code                           477377 non-null int64
# Crime Code Description               477377 non-null object
# MO Codes                             392557 non-null object
# Victim Age                           399952 non-null float64
# Victim Sex                           470422 non-null object
# Victim Descent                       469708 non-null object
# Premise Code                         477352 non-null float64
# Premise Description                  477352 non-null object
# Address                              477377 non-null object
# Cross Street                         456189 non-null object
# Location                             477377 non-null object
# Zip Codes                            476984 non-null float64
# Census Tracts                        470912 non-null float64
# Precinct Boundaries                  474312 non-null float64
# LA Specific Plans                    175632 non-null float64
# Council Districts                    471711 non-null float64
# Neighborhood Councils (Certified)    453529 non-null float64
# dtypes: float64(8), int64(5), object(11)
# memory usage: 87.4+ MB

# %% [markdown]
# ## Cleaning Data

# %%
dfclean = df.drop(columns=['DR Number', #unique value but we have index
        'Date Reported', #repetitive series
        'MO Codes', #mostly NaN values
        'Crime Code', #repetitive
        'Crime Code Description', #uniform data
       'LA Specific Plans', #unrelated data with NaN values
        'Area ID', #repetitive data
       'Premise Description',#useless data 
        'Neighborhood Councils (Certified)', #irrelevant
        'Precinct Boundaries', #irrelevant
        'Council Districts', # irrelevant
        'Census Tracts', #meaningless data
                ])
dfclean.columns = ['date','time','area','district','victim_Age','victim_sex','victim_race','premise','address',
             'cross_street','location','zip']
dfclean.head()
# Out:
#                       date  time         area  district  victim_Age  \
# 0  2019-06-22T00:00:00.000  1150      Mission      1985        32.0
# 1  2019-06-22T00:00:00.000  1600    Southwest       357        27.0
# 2  2019-06-22T00:00:00.000   650  West Valley      1001        20.0
# 3  2019-06-22T00:00:00.000   525      Topanga      2145        44.0
# 4  2019-06-22T00:00:00.000   245  N Hollywood      1543        43.0
#
#   victim_sex victim_race  premise                          address  \
# 0          M           H    101.0  PARTHENIA                    ST
# 1          M           H    101.0                        JEFFERSON
# 2          F           H    101.0                           ROSCOE
# 3          F           H    101.0  VICTORY                      BL
# 4          F           H    101.0  LAUREL CANYON                BL
#
#                       cross_street  \
# 0  TOBIAS                       AV
# 1                         CATALINA
# 2                          SHIRLEY
# 3  SHOUP                        AV
# 4  MAGNOLIA                     BL
#
#                                             location      zip
# 0  {'latitude': '34.2279', 'human_address': '{"ad...  19730.0
# 1  {'latitude': '34.0255', 'human_address': '{"ad...  22724.0
# 2  {'latitude': '34.2204', 'human_address': '{"ad...  18909.0
# 3  {'latitude': '34.1865', 'human_address': '{"ad...   4278.0
# 4  {'latitude': '34.1649', 'human_address': '{"ad...   8890.0

# %% [markdown]
# ## victim_race

# %%
# country_description = {'H':'Hispanic', 'B':'Black', 'O':'Unknown', 'W':'White', 'X':'Unknown', '-':'Unknown',
#              'A':'Asian', 'K':'Korean', 'C':'Chinese', 'F':' ', 'U':' ',
#              'J':'Japanese', 'P':'Pacific Islander', 'V':'Vietnese', 'Z':' ',
#              'I':'American Indian', 'G':'Pacific Islander', 'S':' ', 'D':' ', 'L':' '}
race_description = {'H':'Hispanic', 'B':'Black', 'O':'Unknown', 'W':'White', 'X':'Unknown', '-':'Unknown',
             'A':'Asian', 'K':'Asian', 'C':'Asian', 'F':'Asian', 'U':'Pacific Islander',
             'J':'Asian', 'P':'Pacific Islander', 'V':'Asian', 'Z':'Asian',
             'I':'American Indian', 'G':'Pacific Islander', 'S':'Pacific Islander', 'D':'Asian', 'L':'Asian'}
dfclean.victim_race = dfclean.victim_race.map(race_description)
dfclean.head()
# Out:
#                       date  time         area  district  victim_Age  \
# 0  2019-06-22T00:00:00.000  1150      Mission      1985        32.0
# 1  2019-06-22T00:00:00.000  1600    Southwest       357        27.0
# 2  2019-06-22T00:00:00.000   650  West Valley      1001        20.0
# 3  2019-06-22T00:00:00.000   525      Topanga      2145        44.0
# 4  2019-06-22T00:00:00.000   245  N Hollywood      1543        43.0
#
#   victim_sex victim_race  premise                          address  \
# 0          M    Hispanic    101.0  PARTHENIA                    ST
# 1          M    Hispanic    101.0                        JEFFERSON
# 2          F    Hispanic    101.0                           ROSCOE
# 3          F    Hispanic    101.0  VICTORY                      BL
# 4          F    Hispanic    101.0  LAUREL CANYON                BL
#
#                       cross_street  \
# 0  TOBIAS                       AV
# 1                         CATALINA
# 2                          SHIRLEY
# 3  SHOUP                        AV
# 4  MAGNOLIA                     BL
#
#                                             location      zip
# 0  {'latitude': '34.2279', 'human_address': '{"ad...  19730.0
# 1  {'latitude': '34.0255', 'human_address': '{"ad...  22724.0
# 2  {'latitude': '34.2204', 'human_address': '{"ad...  18909.0
# 3  {'latitude': '34.1865', 'human_address': '{"ad...   4278.0
# 4  {'latitude': '34.1649', 'human_address': '{"ad...   8890.0

# %% [markdown]
# ## Formatting Date and Time

# %%
#create bins to extract hour from 'time'
bins = []
hour = []
for i in range (0,24):
    bins.append(99*i+i-1)
    hour.append(i)
hour.pop(-1)
dfclean['hour'] = pd.cut(dfclean['time'],bins,labels=hour)
dfclean.head()
# Out:
#         date  time         area  district  victim_Age victim_sex victim_race  \
# 0 2019-06-22  1150      Mission      1985        32.0          M    Hispanic
# 1 2019-06-22  1600    Southwest       357        27.0          M    Hispanic
# 2 2019-06-22   650  West Valley      1001        20.0          F    Hispanic
# 3 2019-06-22   525      Topanga      2145        44.0          F    Hispanic
# 4 2019-06-22   245  N Hollywood      1543        43.0          F    Hispanic
#
#    premise                          address                     cross_street  \
# 0    101.0  PARTHENIA                    ST  TOBIAS                       AV
# 1    101.0                        JEFFERSON                         CATALINA
# 2    101.0                           ROSCOE                          SHIRLEY
# 3    101.0  VICTORY                      BL  SHOUP                        AV
# 4    101.0  LAUREL CANYON                BL  MAGNOLIA                     BL
#
#                                             location      zip hour
# 0  {'latitude': '34.2279', 'human_address': '{"ad...  19730.0   11
# 1  {'latitude': '34.0255', 'human_address': '{"ad...  22724.0   16
# 2  {'latitude': '34.2204', 'human_address': '{"ad...  18909.0    6
# 3  {'latitude': '34.1865', 'human_address': '{"ad...   4278.0    5
# 4  {'latitude': '34.1649', 'human_address': '{"ad...   8890.0    2

# %% [markdown]
# ## Longitude and Latitude

# %%
import ast

# %%
dfclean["lat"] = dfclean["location"].apply(lambda u: float(ast.literal_eval(u)["latitude"]))
dfclean["lon"] = dfclean["location"].apply(lambda u: float(ast.literal_eval(u)["longitude"]))

# %%
dfclean.head(10)
# Out:
#                       date  time         area  district  victim_Age  \
# 0  2019-06-22T00:00:00.000  1150      Mission      1985        32.0
# 1  2019-06-22T00:00:00.000  1600    Southwest       357        27.0
# 2  2019-06-22T00:00:00.000   650  West Valley      1001        20.0
# 3  2019-06-22T00:00:00.000   525      Topanga      2145        44.0
# 4  2019-06-22T00:00:00.000   245  N Hollywood      1543        43.0
# 5  2019-06-22T00:00:00.000  1030   Devonshire      1722         NaN
# 6  2019-06-22T00:00:00.000   109     Van Nuys       904         NaN
# 7  2019-06-22T00:00:00.000  1320  N Hollywood      1543        40.0
# 8  2019-06-22T00:00:00.000   110     Van Nuys       911         NaN
# 9  2019-06-22T00:00:00.000   830     Foothill      1675         NaN
#
#   victim_sex victim_race  premise                          address  \
# 0          M    Hispanic    101.0  PARTHENIA                    ST
# 1          M    Hispanic    101.0                        JEFFERSON
# 2          F    Hispanic    101.0                           ROSCOE
# 3          F    Hispanic    101.0  VICTORY                      BL
# 4          F    Hispanic    101.0  LAUREL CANYON                BL
# 5          X     Unknown    101.0                           JORDAN
# 6          M     Unknown    101.0  RAYMER                       ST
# 7          M    Hispanic    101.0  LAUREL CANYON                BL
# 8          X     Unknown    101.0  ORION                        AV
# 9          M    Hispanic    101.0  PENDLETON                    ST
#
#                       cross_street  \
# 0  TOBIAS                       AV
# 1                         CATALINA
# 2                          SHIRLEY
# 3  SHOUP                        AV
# 4  MAGNOLIA                     BL
# 5                         HIAWATHA
# 6  KESTER                       AV
# 7  ALBERS                       ST
# 8  SHERMAN                      WY
# 9  GLENOAKS                     BL
#
#                                             location      zip      lat  \
# 0  {'latitude': '34.2279', 'human_address': '{"ad...  19730.0  34.2279
# 1  {'latitude': '34.0255', 'human_address': '{"ad...  22724.0  34.0255
# 2  {'latitude': '34.2204', 'human_address': '{"ad...  18909.0  34.2204
# 3  {'latitude': '34.1865', 'human_address': '{"ad...   4278.0  34.1865
# 4  {'latitude': '34.1649', 'human_address': '{"ad...   8890.0  34.1649
# 5  {'latitude': '34.2591', 'human_address': '{"ad...   4284.0  34.2591
# 6  {'latitude': '34.2138', 'human_address': '{"ad...  19733.0  34.2138
# 7  {'latitude': '34.1704', 'human_address': '{"ad...   8890.0  34.1704
# 8  {'latitude': '34.2012', 'human_address': '{"ad...  19734.0  34.2012
# 9  {'latitude': '34.2364', 'human_address': '{"ad...  19335.0  34.2364
#
#         lon
# 0 -118.4516
# 1 -118.2937
# 2 -118.5579
# 3 -118.6146
# 4 -118.3965
# 5 -118.6039
# 6 -118.4618
# 7 -118.3965
# 8 -118.4706
# 9 -118.3761

# %%
dfclean = dfclean.drop(columns=['location'])
dfclean.to_csv('Data/Clean/cleaned_data.csv',index=False)
