# %%
#import modules for the analysis environment
import os
import matplotlib.pyplot as plta
import matplotlib as plt
import matplotlib.patches as mpatches
import pandas as pd
import numpy as np
import requests
import datetime
import ast
import gmaps
import datetime
# from config import gkey

#read cleaned csv file
df = pd.read_csv("Data/clean_data/clean_data.csv")
df.head()
# Out:
#          date  time         area  district  victim_age victim_sex victim_race  \
# 0  07/06/2019  2355  N Hollywood      1591        99.0       Male     Unknown
# 1  07/06/2019   500     Foothill      1677        45.0       Male       White
# 2  07/06/2019  1130  West Valley      1028        25.0       Male       Asian
# 3  07/06/2019  1415    Northeast      1153        29.0       Male     Unknown
# 4  07/06/2019  1230      Central       192        41.0       Male     Unknown
#
#   premise                          address              location
# 0  STREET  GOODLAND                     AV  (34.1371, -118.4062)
# 1  STREET  GLENOAKS                     BL  (34.2249, -118.3617)
# 2  STREET  SHERMAN                      WY  (34.2012, -118.4989)
# 3  STREET  LOS FELIZ                    BL  (34.1081, -118.3078)
# 4  STREET  GRAND                        AV  (34.0384, -118.2646)

# %%
# Create DataFrame with the total counts of each ethnicity
sex_race_counts = pd.DataFrame(df['victim_sex'].value_counts())
sex_race_counts
# Out:
#          victim_sex
# Male         234600
# Female       165158
# Unknown         963

# %%
sex_pct = sex_race_counts/sex_race_counts.sum()
sex_pct
sex_pct = sex_pct.loc[["Male", "Female"]]
sex_pct
# Out:
#         victim_sex
# Male      0.585445
# Female    0.412152

# %%
gender_pop = {"Male": "0.492531",
              "Female": "0.507468"}
gender_pop
# Out:
# {'Male': '0.492531', 'Female': '0.507468'}

# %%
sex_pct["pop_pct"] = pd.Series(gender_pop)
sex_pct
# Out:
#         victim_sex   pop_pct
# Male      0.585445  0.492531
# Female    0.412152  0.507468

# %%
male_pct = 4982799/10116705
print(male_pct)

female_pct = 5133906/10116705
print(female_pct)

male_ratio = .585445/male_pct
print(male_ratio)

female_ratio = .412152/female_pct
print(female_ratio)
# Out:
# 0.49253180754010323
# 0.5074681924598968
# 1.1886440449885696
# 0.8121730703990294

# %%
# Create DataFrame with the total counts of each ethnicity
age_race_counts = pd.DataFrame(df['victim_age'].value_counts())
age_race_counts
# Out:
#       victim_age
# 30.0       13940
# 25.0       13048
# 24.0       11507
# 27.0       11422
# 28.0       11329
# 26.0       11251
# 40.0       11204
# 35.0       11178
# 23.0       11146
# 50.0       10690
# 29.0       10659
# 22.0       10612
# 31.0       10031
# 32.0        9734
# 21.0        9393
# 33.0        9189
# 45.0        9021
# 34.0        8919
# 20.0        8672
# 36.0        8458
# 37.0        8190
# 38.0        8108
# 39.0        7784
# 41.0        7678
# 42.0        7586
# 43.0        7380
# 44.0        7248
# 46.0        7228
# 49.0        7165
# 47.0        7129
# ...          ...
# 18.0         655
# 80.0         624
# 79.0         622
# 81.0         577
# 83.0         461
# 82.0         449
# 84.0         376
# 85.0         331
# 86.0         258
# 87.0         231
# 19.0         191
# 89.0         186
# 88.0         173
# 90.0         156
# 17.0          94
# 91.0          91
# 92.0          80
# 94.0          51
# 95.0          48
# 93.0          47
# 96.0          40
# 98.0          34
# 97.0          31
# 16.0          23
# 15.0          22
# 14.0          11
# 12.0           6
# 13.0           6
# 11.0           2
# 10.0           2
#
# [90 rows x 1 columns]

# %%
# Create DataFrame with the total counts of each ethnicity
victim_race_counts = pd.DataFrame(df['victim_race'].value_counts())
victim_race_counts
# Out:
#                   victim_race
# Hispanic               156131
# White                  101618
# Unknown                 60669
# Black                   58343
# Asian                   23383
# Pacific Islander          442
# American Indian           135

# %%
# Remove Unknown victims from DataFrame
updated_victim_race = victim_race_counts.loc[['Hispanic','White','Black',
                                              'Asian','Pacific Islander','American Indian'],
                                             ['victim_race']]
updated_victim_race
# Out:
#                   victim_race
# Hispanic               156131
# White                  101618
# Black                   58343
# Asian                   23383
# Pacific Islander          442
# American Indian           135

# %%
#Calculate the percentage of total crashes per ethinicity 
percent_victim_race = updated_victim_race["victim_race"]/updated_victim_race["victim_race"].sum()*100

# Add a new colum display the calculated percentage
updated_victim_race["crash_population"] = percent_victim_race
updated_victim_race
# Out:
#                   victim_race  crash_population
# Hispanic               156131         45.913860
# White                  101618         29.883077
# Black                   58343         17.157082
# Asian                   23383          6.876301
# Pacific Islander          442          0.129980
# American Indian           135          0.039700

# %%
# Display only the percentage of crashes per ethnicity
pct_race_df = pd.DataFrame(updated_victim_race["crash_population"])

# Format percentage calculations with two digits and percentage sign
# pct_race_df.style.format({"crash_population":"{:,.2f}%"})
pct_race_df
# Out:
#                   crash_population
# Hispanic                 45.913860
# White                    29.883077
# Black                    17.157082
# Asian                     6.876301
# Pacific Islander          0.129980
# American Indian           0.039700

# %% [markdown]
# LA Population Composition by race
# >- Hispanic: 48.2%
# - White (non-hispanic): 28.5%
# - Black: 9.0%
# - Asian: 11.6%
# - Pacific Islander: 0.2%
# - American Indian: 0.4%
# - Other: 0.6%
#
# src: https://statisticalatlas.com/place/California/Los-Angeles/Race-and-Ethnicity

# %%
ethn_dict = {"Hispanic":"48.2", 
             "White":"28.5", 
             "Black":"9.0", 
             "Asian":"11.6", 
             "Pacific Islander":"0.2", 
             "American Indian":"0.4"}

pct_race_df["LA_Population"] = pd.Series(ethn_dict)
multibar = pct_race_df.style.format({"crash_population":"{:,.2f}"})
multibar
# Out:
# <style  type="text/css" >
# </style><table id="T_7e3878be_a82d_11e9_896b_38baf8974950" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >crash_population</th>        <th class="col_heading level0 col1" >LA_Population</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7e3878be_a82d_11e9_896b_38baf8974950level0_row0" class="row_heading level0 row0" >Hispanic</th>
#                         <td id="T_7e3878be_a82d_11e9_896b_38baf8974950row0_col0" class="data row0 col0" >45.91</td>
#                         <td id="T_7e3878be_a82d_11e9_896b_38baf8974950row0_col1" class="data row0 col1" >48.2</td>
#             </tr>
#             <tr>
#                         <th id="T_7e3878be_a82d_11e9_896b_38baf8974950level0_row1" class="row_heading level0 row1" >White</th>
#                         <td id="T_7e3878be_a82d_11e9_896b_38baf8974950row1_col0" class="data row1 col0" >29.88</td>
#                         <td id="T_7e3878be_a82d_11e9_896b_38baf8974950row1_col1" class="data row1 col1" >28.5</td>
#             </tr>
#             <tr>
#                         <th id="T_7e3878be_a82d_11e9_896b_38baf8974950level0_row2" class="row_heading level0 row2" >Black</th>
#                         <td id="T_7e3878be_a82d_11e9_896b_38baf8974950row2_col0" class="data row2 col0" >17.16</td>
#                         <td id="T_7e3878be_a82d_11e9_896b_38baf8974950row2_col1" class="data row2 col1" >9.0</td>
#             </tr>
#             <tr>
#                         <th id="T_7e3878be_a82d_11e9_896b_38baf8974950level0_row3" class="row_heading level0 row3" >Asian</th>
#                         <td id="T_7e3878be_a82d_11e9_896b_38baf8974950row3_col0" class="data row3 col0" >6.88</td>
#                         <td id="T_7e3878be_a82d_11e9_896b_38baf8974950row3_col1" class="data row3 col1" >11.6</td>
#             </tr>
#             <tr>
#                         <th id="T_7e3878be_a82d_11e9_896b_38baf8974950level0_row4" class="row_heading level0 row4" >Pacific Islander</th>
#                         <td id="T_7e3878be_a82d_11e9_896b_38baf8974950row4_col0" class="data row4 col0" >0.13</td>
#                         <td id="T_7e3878be_a82d_11e9_896b_38baf8974950row4_col1" class="data row4 col1" >0.2</td>
#             </tr>
#             <tr>
#                         <th id="T_7e3878be_a82d_11e9_896b_38baf8974950level0_row5" class="row_heading level0 row5" >American Indian</th>
#                         <td id="T_7e3878be_a82d_11e9_896b_38baf8974950row5_col0" class="data row5 col0" >0.04</td>
#                         <td id="T_7e3878be_a82d_11e9_896b_38baf8974950row5_col1" class="data row5 col1" >0.4</td>
#             </tr>
#     </tbody></table>

# %%
test_df = pd.DataFrame({"Ratio" : [95, 105, 191, 59, 65, 10]})

xaxis = ("H", "W", "B", "A", "P", "I")
crash_pop = (45.91, 29.88, 17.16, 6.88, 0.13, .04)
la_pop = (48.2, 28.5, 9, 11.6, .2, .4)

ind = np.arange(len(xaxis))
width = .55

plta.bar(ind - width/2, crash_pop, width=.52, color="black", label="Crash Population")
plta.bar(ind + width/2, la_pop, width=.52, color="b", label="LA Population")
test_df["Ratio"].plot(kind="line", linestyle=':', marker="o", color="r", secondary_y=True)

plta.title("Ethnicity by Victim Crash and LA Population")
plta.ylabel("Population %")
# plta.yaxis(tick_right())
# plta.yaxis(tick_left())
plta.legend(loc="best")
plta.xticks(ind + width/20, ("Hispanic", "White", "Black", "Asian", "Pacific Islander", "American Indian"), rotation = 40)

plta.spines['right'].set_visible(False)
plta.spines['top'].set_visible(False)
plta.spines['left'].set_visible(False)
plta.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-5e2b8593251f> in <module>
#      19 plta.xticks(ind + width/20, ("Hispanic", "White", "Black", "Asian", "Pacific Islander", "American Indian"), rotation = 40)
#      20
# ---> 21 plta.spines['right'].set_visible(False)
#      22 plta.spines['top'].set_visible(False)
#      23 plta.spines['left'].set_visible(False)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'spines'

# %%
ratio = [95, 105, 191, 59, 65, 10]
xaxis = ["Hispanic", "White", "Black", "Asian", "Pacific Islander", "American Indian"] 
crash_pop = (45.91, 29.88, 17.16, 6.88, 0.13, .04)
la_pop = (48.2, 28.5, 9, 11.6, .2, .4)
width = 0.35
ind = np.arange(len(xaxis))
crash_data = pd.DataFrame(crash_pop,xaxis)
crash_data[1] = la_pop
crash_data = crash_data.rename(columns = {0:'crash',1:'population'})
crash_fig = crash_data.plot(kind='bar', use_index=True)
line_data = crash_fig.twinx()
line_fig = line_data.plot(ratio,linestyle='-',marker='o',color='red')

plta.title("Ethnicity by Victim Crash and LA Population")
plta.ylabel("Ratio %")
plta.tick_params(axis='x', rotation=100)

# %%
ratio = [95, 105, 191, 59, 65, 10]
xaxis = ["Hispanic", "White", "Black", "Asian", "Pacific Islander", "American Indian"] 
crash = (45.91, 29.88, 17.16, 6.88, 0.13, .04)
population = (48.2, 28.5, 9, 11.6, .2, .4)
width = 0.35
ind = np.arange(len(xaxis))
# crash_data = pd.DataFrame(crash_pop,xaxis)
# crash_data[1] = la_pop
crash_data = crash_data.rename(columns = {0:'crash',1:'population'})

crash_fig = crash_data.plot(kind='bar', use_index=True)
plta.bar(ind - width/2, crash, width=.35, color="black", label="Crash Population")
plta.bar(ind + width/2, population, width=.35, color="gray", label="LA Population")
line_data = crash_fig.twinx()
line_fig = line_data.plot(ratio,linestyle=':',marker='o',color='r')

black_patch = mpatches.Patch(color='black', label='Crash')
# gray_patch = mpatches.Patch(color='gray', label='Population')
plt.legend(handles=[black_patch])

plt.show()
plta.title("Ethnicity by Victim Crash and LA Population")
plta.ylabel("Ratio %")
plta.tick_params(axis='x', rotation=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-c42973c18e8b> in <module>
#      17 black_patch = mpatches.Patch(color='black', label='Crash')
#      18 # gray_patch = mpatches.Patch(color='gray', label='Population')
# ---> 19 plt.legend(handles=[black_patch])
#      20
#      21 plt.show()
#
# TypeError: 'module' object is not callable

# %%
ratio = [95, 105, 191, 59, 65, 10]
xaxis = ["Hispanic", "White", "Black", "Asian", "Pacific Islander", "American Indian"] 
crash = (45.91, 29.88, 17.16, 6.88, 0.13, .04)
population = (48.2, 28.5, 9, 11.6, .2, .4)
width = 0.35
ind = np.arange(len(xaxis))
# crash_data = pd.DataFrame(crash_pop,xaxis)
# crash_data[1] = la_pop
crash_data = crash_data.rename(columns = {0:'crash',1:'population'})

crash_fig = crash_data.plot(kind='bar', use_index=True)
plta.bar(ind - width/2, crash, width=.35, color="black", label="Crash Population")
plta.bar(ind + width/2, population, width=.35, color="gray", label="LA Population")
line_data = crash_fig.twinx()
line_fig = line_data.plot(ratio,linestyle=':',marker='o',color='r')


# plta.title("Ethnicity by Victim Crash and LA Population")
plta.ylabel("Ratio %")
plta.tick_params(axis='x', rotation=100)

# %%
xaxis = ("H", "W", "B", "A", "P", "I")
crash_pop = (45.91, 29.88, 17.16, 6.88, 0.13, .04)
la_pop = (48.2, 28.5, 9, 11.6, .2, .4)

ind = np.arange(len(xaxis))
width = 0.35

plta.bar(ind - width/2, crash_pop, width, color="black", label="Crash Population")
plta.bar(ind + width/2, la_pop, width, color="gray", label="LA Population")

plta.title("Ethnicity by Victim Crash and LA Population")
plta.ylabel("Population %")

plta.xticks(ind + width/20, ("Hispanic", "White", "Black", "Asian", "Pacific Islander", "American Indian"), rotation = 40)
plta.legend(loc="best")

plta.show()

# %%
xaxis = ("H", "W", "B", "A", "P", "I")
crash_pop = (45.91, 29.88, 17.16, 6.88, 0.13, .04)
la_pop = (48.2, 28.5, 9, 11.6, .2, .4)

ind = np.arange(len(xaxis))
width = 0.35

plta.bar(ind - width/2, crash_pop, width, color="black", label="Crash Population")
plta.bar(ind + width/2, la_pop, width, color="gray", label="LA Population")

# plta.title("Ethnicity by Victim Crash and LA Population")
plta.ylabel("Population %")

plta.xticks(ind + width/20, ("Hispanic", "White", "Black", "Asian", "Pacific Islander", "American Indian"), rotation = 40)
plta.legend(loc="best")

plta.show()

# %% [markdown]
# ## Age mean per Ethnicity
