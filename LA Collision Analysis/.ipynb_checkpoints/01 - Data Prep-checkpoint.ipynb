# %% [markdown]
# # Los Angeles Traffic Collision Data Cleaning
# ---
#
# ## Summary:
# 1. Import Modules and Data
# 2. Data Exploration
# 3. Data Cleaning
#     1. Drop Useless Columns
#     2. Drop Null Values
#     3. Rename Columns
#     4. Map Ethnicities
#     5. Map Genders
# 4. Export Clean Data
#
#
# Data Source: https://data.lacity.org/A-Safe-City/Traffic-Collision-Data-from-2010-to-Present/d5tf-ez2w

# %% [markdown]
# ## 1. Import Modules and Data

# %%
import pandas as pd

# Read csv file
df = pd.read_csv("Data/raw_data/traffic-collision-data-from-2010-to-present.csv")
df.head()
# Out:
#    DR Number            Date Reported            Date Occurred  Time Occurred  \
# 0  191912240  2019-06-22T00:00:00.000  2019-06-22T00:00:00.000           1150
# 1  190315354  2019-06-22T00:00:00.000  2019-06-22T00:00:00.000           1600
# 2  191011360  2019-06-22T00:00:00.000  2019-06-22T00:00:00.000            650
# 3  192111796  2019-06-22T00:00:00.000  2019-06-22T00:00:00.000            525
# 4  191512949  2019-06-22T00:00:00.000  2019-06-22T00:00:00.000            245
#
#    Area ID    Area Name  Reporting District  Crime Code  \
# 0       19      Mission                1985         997
# 1        3    Southwest                 357         997
# 2       10  West Valley                1001         997
# 3       21      Topanga                2145         997
# 4       15  N Hollywood                1543         997
#
#   Crime Code Description MO Codes  ...  Premise Description  \
# 0      TRAFFIC COLLISION      NaN  ...               STREET
# 1      TRAFFIC COLLISION      NaN  ...               STREET
# 2      TRAFFIC COLLISION      NaN  ...               STREET
# 3      TRAFFIC COLLISION      NaN  ...               STREET
# 4      TRAFFIC COLLISION      NaN  ...               STREET
#
#                            Address                     Cross Street  \
# 0  PARTHENIA                    ST  TOBIAS                       AV
# 1                        JEFFERSON                         CATALINA
# 2                           ROSCOE                          SHIRLEY
# 3  VICTORY                      BL  SHOUP                        AV
# 4  LAUREL CANYON                BL  MAGNOLIA                     BL
#
#                                             Location Zip Codes Census Tracts  \
# 0  {'latitude': '34.2279', 'human_address': '{"ad...   19730.0         144.0
# 1  {'latitude': '34.0255', 'human_address': '{"ad...   22724.0         691.0
# 2  {'latitude': '34.2204', 'human_address': '{"ad...   18909.0         101.0
# 3  {'latitude': '34.1865', 'human_address': '{"ad...    4278.0         297.0
# 4  {'latitude': '34.1649', 'human_address': '{"ad...    8890.0         205.0
#
#   Precinct Boundaries LA Specific Plans  Council Districts  \
# 0               417.0               NaN                3.0
# 1               913.0               7.0               14.0
# 2              1545.0               NaN                2.0
# 3              1473.0               NaN                4.0
# 4              1332.0              17.0                5.0
#
#    Neighborhood Councils (Certified)
# 0                               59.0
# 1                               32.0
# 2                               65.0
# 3                               49.0
# 4                               39.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 2. Data Exploration
# ---

# %%
# Explore data-set to see what columns exist and their respective data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477377 entries, 0 to 477376
# Data columns (total 24 columns):
# DR Number                            477377 non-null int64
# Date Reported                        477377 non-null object
# Date Occurred                        477377 non-null object
# Time Occurred                        477377 non-null int64
# Area ID                              477377 non-null int64
# Area Name                            477377 non-null object
# Reporting District                   477377 non-null int64
# Crime Code                           477377 non-null int64
# Crime Code Description               477377 non-null object
# MO Codes                             392557 non-null object
# Victim Age                           399952 non-null float64
# Victim Sex                           470422 non-null object
# Victim Descent                       469708 non-null object
# Premise Code                         477352 non-null float64
# Premise Description                  477352 non-null object
# Address                              477377 non-null object
# Cross Street                         456189 non-null object
# Location                             477377 non-null object
# Zip Codes                            476984 non-null float64
# Census Tracts                        470912 non-null float64
# Precinct Boundaries                  474312 non-null float64
# LA Specific Plans                    175632 non-null float64
# Council Districts                    471711 non-null float64
# Neighborhood Councils (Certified)    453529 non-null float64
# dtypes: float64(8), int64(5), object(11)
# memory usage: 87.4+ MB

# %% [markdown]
# ## 3. Data Cleaning

# %% [markdown]
# ### a) Drop Useless Columns

# %%
# Drop columns that will not help during the analysis
drop_columns_df = df.drop(columns=[
    "DR Number", # Not useful for analysis
    "Date Reported", # More interested in Date Occured
    "Area ID", # Could use Area Name
    "Crime Code", # Uniform data: "997"
    "Crime Code Description", # Uniform data: "TRAFFIC COLLISION"
    "MO Codes", # Too many null values
    "Premise Code", # Could use Premise Description
    "Cross Street"]) # Could use Address or Location

drop_columns_df.head()
# Out:
#              Date Occurred  Time Occurred    Area Name  Reporting District  \
# 0  2019-06-22T00:00:00.000           1150      Mission                1985
# 1  2019-06-22T00:00:00.000           1600    Southwest                 357
# 2  2019-06-22T00:00:00.000            650  West Valley                1001
# 3  2019-06-22T00:00:00.000            525      Topanga                2145
# 4  2019-06-22T00:00:00.000            245  N Hollywood                1543
#
#    Victim Age Victim Sex Victim Descent Premise Description  \
# 0        32.0          M              H              STREET
# 1        27.0          M              H              STREET
# 2        20.0          F              H              STREET
# 3        44.0          F              H              STREET
# 4        43.0          F              H              STREET
#
#                            Address  \
# 0  PARTHENIA                    ST
# 1                        JEFFERSON
# 2                           ROSCOE
# 3  VICTORY                      BL
# 4  LAUREL CANYON                BL
#
#                                             Location  Zip Codes  \
# 0  {'latitude': '34.2279', 'human_address': '{"ad...    19730.0
# 1  {'latitude': '34.0255', 'human_address': '{"ad...    22724.0
# 2  {'latitude': '34.2204', 'human_address': '{"ad...    18909.0
# 3  {'latitude': '34.1865', 'human_address': '{"ad...     4278.0
# 4  {'latitude': '34.1649', 'human_address': '{"ad...     8890.0
#
#    Census Tracts  Precinct Boundaries  LA Specific Plans  Council Districts  \
# 0          144.0                417.0                NaN                3.0
# 1          691.0                913.0                7.0               14.0
# 2          101.0               1545.0                NaN                2.0
# 3          297.0               1473.0                NaN                4.0
# 4          205.0               1332.0               17.0                5.0
#
#    Neighborhood Councils (Certified)
# 0                               59.0
# 1                               32.0
# 2                               65.0
# 3                               49.0
# 4                               39.0

# %% [markdown]
# ### b) Drop Null Values

# %%
# See how many null values exist for each column
pd.isnull(drop_columns_df).sum()
# Out:
# Date Occurred                             0
# Time Occurred                             0
# Area Name                                 0
# Reporting District                        0
# Victim Age                            77425
# Victim Sex                             6955
# Victim Descent                         7669
# Premise Description                      25
# Address                                   0
# Location                                  0
# Zip Codes                               393
# Census Tracts                          6465
# Precinct Boundaries                    3065
# LA Specific Plans                    301745
# Council Districts                      5666
# Neighborhood Councils (Certified)     23848
# dtype: int64

# %%
# Drop all null values
drop_nulls_df = drop_columns_df.dropna()

# %%
# Check row counts for each column after dropping nulls
drop_nulls_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132467 entries, 1 to 477375
# Data columns (total 16 columns):
# Date Occurred                        132467 non-null object
# Time Occurred                        132467 non-null int64
# Area Name                            132467 non-null object
# Reporting District                   132467 non-null int64
# Victim Age                           132467 non-null float64
# Victim Sex                           132467 non-null object
# Victim Descent                       132467 non-null object
# Premise Description                  132467 non-null object
# Address                              132467 non-null object
# Location                             132467 non-null object
# Zip Codes                            132467 non-null float64
# Census Tracts                        132467 non-null float64
# Precinct Boundaries                  132467 non-null float64
# LA Specific Plans                    132467 non-null float64
# Council Districts                    132467 non-null float64
# Neighborhood Councils (Certified)    132467 non-null float64
# dtypes: float64(7), int64(2), object(7)
# memory usage: 17.2+ MB

# %% [markdown]
# ### c) Rename Columns

# %%
# Rename columns without spaces
rename_columns_df = drop_nulls_df.rename(columns={
    "Date Occurred" : "date",
    "Time Occurred" : "time",
    "Area Name" : "area",
    "Reporting District" : "district",
    "Victim Age" : "victim_age",
    "Victim Sex" : "victim_sex",
    "Victim Descent" : "victim_race",
    "Premise Description" : "premise",
    "Address" : "address",
    "Location" : "location"})

rename_columns_df.head()
# Out:
#                        date  time         area  district  victim_age  \
# 1   2019-06-22T00:00:00.000  1600    Southwest       357        27.0
# 4   2019-06-22T00:00:00.000   245  N Hollywood      1543        43.0
# 26  2019-06-21T00:00:00.000  1550      Rampart       238        23.0
# 29  2019-06-21T00:00:00.000  1010      Rampart       269        35.0
# 36  2019-06-21T00:00:00.000    40    Southwest       362        25.0
#
#    victim_sex victim_race premise                                  address  \
# 1           M           H  STREET                                JEFFERSON
# 4           F           H  STREET          LAUREL CANYON                BL
# 26          M           W  STREET  1400    COURT                        ST
# 29          F           B  STREET          8TH                          ST
# 36          M           H  STREET          MARTIN LUTHER KING JR        BL
#
#                                              location  Zip Codes  \
# 1   {'latitude': '34.0255', 'human_address': '{"ad...    22724.0
# 4   {'latitude': '34.1649', 'human_address': '{"ad...     8890.0
# 26  {'latitude': '34.0647', 'human_address': '{"ad...    23444.0
# 29  {'latitude': '34.0496', 'human_address': '{"ad...    23078.0
# 36  {'latitude': '34.0176', 'human_address': '{"ad...    22725.0
#
#     Census Tracts  Precinct Boundaries  LA Specific Plans  Council Districts  \
# 1           691.0                913.0                7.0               14.0
# 4           205.0               1332.0               17.0                5.0
# 26          548.0                397.0               54.0               11.0
# 29          568.0               1378.0               54.0               11.0
# 36          763.0               1024.0                7.0               12.0
#
#     Neighborhood Councils (Certified)
# 1                                32.0
# 4                                39.0
# 26                               31.0
# 29                               68.0
# 36                               54.0

# %% [markdown]
# ### d) Map Ethnicities
#
# Ethnicity Map Documentation: https://data.lacity.org/A-Safe-City/Traffic-Collision-Data-from-2010-to-Present/d5tf-ez2w

# %%
# Map each respective ethnicity inital into ethnicity groups
race_dict = {'H':'Hispanic', 'B':'Black', 'O':'Unknown', 'W':'White', 'X':'Unknown', '-':'Unknown',
             'A':'Asian', 'K':'Asian', 'C':'Asian', 'F':'Asian', 'U':'Pacific Islander',
             'J':'Asian', 'P':'Pacific Islander', 'V':'Asian', 'Z':'Asian',
             'I':'American Indian', 'G':'Pacific Islander', 'S':'Pacific Islander', 'D':'Asian', 'L':'Asian'}

rename_columns_df["victim_race"] = rename_columns_df["victim_race"].map(race_dict)

map_ethnicities_df = rename_columns_df
map_ethnicities_df.head()
# Out:
#                        date  time         area  district  victim_age  \
# 1   2019-06-22T00:00:00.000  1600    Southwest       357        27.0
# 4   2019-06-22T00:00:00.000   245  N Hollywood      1543        43.0
# 26  2019-06-21T00:00:00.000  1550      Rampart       238        23.0
# 29  2019-06-21T00:00:00.000  1010      Rampart       269        35.0
# 36  2019-06-21T00:00:00.000    40    Southwest       362        25.0
#
#    victim_sex victim_race premise                                  address  \
# 1           M    Hispanic  STREET                                JEFFERSON
# 4           F    Hispanic  STREET          LAUREL CANYON                BL
# 26          M       White  STREET  1400    COURT                        ST
# 29          F       Black  STREET          8TH                          ST
# 36          M    Hispanic  STREET          MARTIN LUTHER KING JR        BL
#
#                                              location  Zip Codes  \
# 1   {'latitude': '34.0255', 'human_address': '{"ad...    22724.0
# 4   {'latitude': '34.1649', 'human_address': '{"ad...     8890.0
# 26  {'latitude': '34.0647', 'human_address': '{"ad...    23444.0
# 29  {'latitude': '34.0496', 'human_address': '{"ad...    23078.0
# 36  {'latitude': '34.0176', 'human_address': '{"ad...    22725.0
#
#     Census Tracts  Precinct Boundaries  LA Specific Plans  Council Districts  \
# 1           691.0                913.0                7.0               14.0
# 4           205.0               1332.0               17.0                5.0
# 26          548.0                397.0               54.0               11.0
# 29          568.0               1378.0               54.0               11.0
# 36          763.0               1024.0                7.0               12.0
#
#     Neighborhood Councils (Certified)
# 1                                32.0
# 4                                39.0
# 26                               31.0
# 29                               68.0
# 36                               54.0

# %% [markdown]
# ### e) Map Genders

# %%
# Map each gender inital into gender groups
map_gender_df = map_ethnicities_df # Set mapped ethnicities equal to a new gender df

gender_dict = {
    'M':'Male', 
    'F':'Female', 
    'X':'Unknown', 
    'H':'Unknown', 
    'N':'Unknown'}

map_gender_df["victim_sex"] = map_gender_df["victim_sex"].map(gender_dict)
map_gender_df.head()
# Out:
#                        date  time         area  district  victim_age  \
# 1   2019-06-22T00:00:00.000  1600    Southwest       357        27.0
# 4   2019-06-22T00:00:00.000   245  N Hollywood      1543        43.0
# 26  2019-06-21T00:00:00.000  1550      Rampart       238        23.0
# 29  2019-06-21T00:00:00.000  1010      Rampart       269        35.0
# 36  2019-06-21T00:00:00.000    40    Southwest       362        25.0
#
#    victim_sex victim_race premise                                  address  \
# 1        Male    Hispanic  STREET                                JEFFERSON
# 4      Female    Hispanic  STREET          LAUREL CANYON                BL
# 26       Male       White  STREET  1400    COURT                        ST
# 29     Female       Black  STREET          8TH                          ST
# 36       Male    Hispanic  STREET          MARTIN LUTHER KING JR        BL
#
#                                              location  Zip Codes  \
# 1   {'latitude': '34.0255', 'human_address': '{"ad...    22724.0
# 4   {'latitude': '34.1649', 'human_address': '{"ad...     8890.0
# 26  {'latitude': '34.0647', 'human_address': '{"ad...    23444.0
# 29  {'latitude': '34.0496', 'human_address': '{"ad...    23078.0
# 36  {'latitude': '34.0176', 'human_address': '{"ad...    22725.0
#
#     Census Tracts  Precinct Boundaries  LA Specific Plans  Council Districts  \
# 1           691.0                913.0                7.0               14.0
# 4           205.0               1332.0               17.0                5.0
# 26          548.0                397.0               54.0               11.0
# 29          568.0               1378.0               54.0               11.0
# 36          763.0               1024.0                7.0               12.0
#
#     Neighborhood Councils (Certified)
# 1                                32.0
# 4                                39.0
# 26                               31.0
# 29                               68.0
# 36                               54.0

# %% [markdown]
# ## 4. Export Clean Data

# %%
# Export cleaned data set into a csv file
map_gender_df.to_csv("data/clean_data/clean_data.csv")
